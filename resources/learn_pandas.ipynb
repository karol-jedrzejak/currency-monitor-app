# %%
import pandas as pd

# %%
df = pd.read_csv('call_activity.csv')
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# ...

# %% [markdown]
# ##Create a datframe from dictionary

# %%
tempDict = {
'Name':['John','Marcus','Anthony'],
'Age':['100','70','30'],
    'Designation':['chief','senior','junior'],
}

# %%
dictDf = pd.DataFrame.from_dict(tempDict)

# %%
dictDf
# Out:
#       Name  Age Designation
# 0     John  100       chief
# 1   Marcus   70      senior
# 2  Anthony   30      junior

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# dtype: object

# %%
df.State.unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
df[df['International plan'] == 'No']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 6       MA             121        510                 No             Yes
# 8       LA             117        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[df['State'] == 'WV']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 9       WV             141        415                Yes             Yes
# 80      WV             144        415                 No              No
# 87      WV             111        510                 No              No
# 180     WV              94        510                Yes             Yes
# 243     WV              85        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3212    WV             144        510                 No             Yes
# 3215    WV              23        510                 No             Yes
# 3269    WV             117        510                Yes              No
# 3324    WV             159        415                 No              No
# 3329    WV              68        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[(df['State'] == 'WV')&(df['International plan'] == 'Yes')]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 9       WV             141        415                Yes             Yes
# 180     WV              94        510                Yes             Yes
# 715     WV             115        510                Yes              No
# 781     WV             112        415                Yes              No
# 1503    WV              57        415                Yes             Yes
# 2468    WV             152        510                Yes             Yes
# 3269    WV             117        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 9                        37              258.6             84.0
# 180                      23              197.1            125.0
# 715                       0              249.9             95.0
# 781                       0              161.9            138.0
# ...

# %%
df.iloc[15]
# Out:
# State                        NY
# Account length              161
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         317.8
# Total eve calls            97.0
# Total eve charge          27.01
# Total night minutes       160.6
# Total night calls         128.0
# Total night charge         7.23
# Total intl minutes          5.4
# Total intl calls              9
# Total intl charge          1.46
# Customer service calls      4.0
# Churn                      True
# Name: 15, dtype: object

# %%
df.iloc[15,0]
# Out:
# 'NY'

# %%
df.iloc[15:18]
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 15    NY             161        415                 No              No
# 16    ID              85        408                 No             Yes
# 17    VT              93        510                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 15                      0                NaN              NaN
# 16                     27                NaN              NaN
# 17                      0                NaN              NaN
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 15               NaN              317.8             97.0             27.01
# 16               NaN              280.9             90.0             23.88
# 17               NaN              218.2            111.0             18.55
#
#     Total night minutes  Total night calls  Total night charge  \
# ...

# %%
state = df.copy()
state.set_index('State',inplace=True)

# %%
state.head()
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
# NJ                         0              243.4            114.0
# OH                         0              299.4             71.0
# OK                         0              166.7            113.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# ...

# %%
state
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
# ...               ...        ...                ...             ...
# AZ                192        415                 No             Yes
# WV                 68        415                 No              No
# RI                 28        510                 No              No
# CT                184        510                Yes              No
# TN                 74        415                 No             Yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# ...

# %%
state.loc['RI']
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# RI                 74        415                 No              No
# RI                145        408                 No             Yes
# RI                 56        415                 No              No
# RI                 99        510                 No              No
# RI                107        415                 No             Yes
# ...               ...        ...                ...             ...
# RI                 33        415                 No              No
# RI                138        510                Yes              No
# RI                 89        415                 No             Yes
# RI                 95        408                 No              No
# RI                 28        510                 No              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# RI                         0              187.7            127.0
# ...

# %%
state.reset_index()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.isnull().sum()
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.to_csv('out.csv')
